# %% [markdown]
# # ProPyCore SDK Examples: Drawings
#
# This notebook contains snippets from the `drawings` submodules: `tiles.py`, `sets.py`, `revisions.py`, and `uploads.py`.

# %%
import os
import dotenv
import json

import ProPyCore

# %% [markdown]
# ## Setup
# You will need to create the connection to your Procore app and then get the details for your company and project.
#
# ### Connection to Procore App
# Ensure you have a `.env` file with the following information included:
# * `CLIENT_ID`: your data connection app's client ID
# * `CLIENT_SECRET`: your data connection app's client secret

# %%
dotenv.load_dotenv()
connection = ProPyCore.procore.Procore(
    client_id=os.getenv("CLIENT_ID"),
    client_secret=os.getenv("CLIENT_SECRET"),
    redirect_uri="urn:ietf:wg:oauth:2.0:oob", # default for data connection apps
    oauth_url="https://app.procore.com", # default for data connection apps
    base_url="https://app.procore.com" # default for data connection apps
)

# %% [markdown]
# ### Get Company Details
# Use the cell below to specify your company name

# %%
companies = connection.companies.get()
for company in companies:
    print(company["name"])

company_name = companies[0]["name"]
# Out:
# Rogers-O`Brien Construction

# %% [markdown]
# Now get the company details

# %%
company = connection.companies.find(identifier=company_name)
projects = connection.projects.get(company_id=company["id"])

# %% [markdown]
# ### Get Project Details
# Specify your project ID

# %%
# Replace with your project ID
project_id = 2685112

# %% [markdown]
# ## Tiles
# Below are snippets from the `tiles.py` submodule, allowing you to access drawing tiles.

# %% [markdown]
# ### `drawings.tiles.get()`
# Fetches all the drawing tiles for a specific drawing revision

# %%
# Replace with your drawing revision ID
drawing_revision_id = 358220391

drawing_tile = connection.drawings.tiles.get(
    company_id=company["id"],
    project_id=project_id,
    drawing_revision_id=drawing_revision_id,
    per_page=100
)

print(json.dumps(drawing_tile, indent=4))
# Out:
# {
#     "max_zoom_level": 2,
#     "tile_size": [
#         750,
#         750
#     ],
#     "zip_url": "https://storage.procore.com/api/v5/files/us-east-1/pro-core.com/358220391_fba57cbd-101f-4628-919b-ee7cc1efbb31.zip?companyId=8089&projectId=2685112&sig=d986c201792264a7d38957d8a170c835c25e6054fadb77e3600ee000bf4438bb",
#     "tiles": [
#         {
#             "id": 1,
#             "x": 0,
#             "y": 0,
#             "z": 0,
#             "url": "deprecated"
#         },
#         {
#             "id": 2,
#             "x": 1,
#             "y": 0,
#             "z": 0,
#             "url": "deprecated"
#         },
#         {
#             "id": 3,
#             "x": 2,
#             "y": 0,
#             "z": 0,
#             "url": "deprecated"
#         },
#         {
#             "id": 4,
#             "x": 0,
#             "y": 1,
#             "z": 0,
#             "url": "deprecated"
#         },
#         {
#             "id": 5,
#             "x": 1,
#             "y": 1,
#             "z": 0,
#             "url": "deprecated"
#         },
#         {
#             "id": 6,
#             "x": 2,
#             "y": 1,
#             "z": 0,
#             "url": "deprecated"
#         },
#         {
#             "id": 7,
#             "x": 0,
#             "y": 0,
#             "z": 1,
#             "url": "deprecated"
#         },
#         {
#             "id": 8,
#             "x": 1,
#             "y": 0,
#             "z": 1,
#             "url": "deprecated"
#         },
#         {
#             "id": 9,
#             "x": 2,
#             "y": 0,
#             "z": 1,
#             "url": "deprecated"
#         },
#         {
#             "id": 10,
#             "x": 3,
#             "y": 0,
#             "z": 1,
#             "url": "deprecated"
#         },
#         {
#             "id": 11,
#             "x": 4,
#             "y": 0,
#             "z": 1,
#             "url": "deprecated"
#         },
#         {
#             "id": 12,
#             "x": 0,
#             "y": 1,
#             "z": 1,
#             "url": "deprecated"
#         },
#         {
#             "id": 13,
#             "x": 1,
#             "y": 1,
#             "z": 1,
#             "url": "deprecated"
#         },
#         {
#             "id": 14,
#             "x": 2,
#             "y": 1,
#             "z": 1,
#             "url": "deprecated"
#         },
#         {
#             "id": 15,
#             "x": 3,
#             "y": 1,
#             "z": 1,
#             "url": "deprecated"
#         },
#         {
#             "id": 16,
#             "x": 4,
#             "y": 1,
#             "z": 1,
#             "url": "deprecated"
#         },
#         {
#             "id": 17,
#             "x": 0,
#             "y": 2,
#             "z": 1,
#             "url": "deprecated"
#         },
#         {
#             "id": 18,
#             "x": 1,
#             "y": 2,
#             "z": 1,
#             "url": "deprecated"
#         },
#         {
#             "id": 19,
#             "x": 2,
#             "y": 2,
#             "z": 1,
#             "url": "deprecated"
#         },
#         {
#             "id": 20,
#             "x": 3,
#             "y": 2,
#             "z": 1,
#             "url": "deprecated"
#         },
#         {
#             "id": 21,
#             "x": 4,
#             "y": 2,
#             "z": 1,
#             "url": "deprecated"
#         },
#         {
#             "id": 22,
#             "x": 0,
#             "y": 3,
#             "z": 1,
#             "url": "deprecated"
#         },
#         {
#             "id": 23,
#             "x": 1,
#             "y": 3,
#             "z": 1,
#             "url": "deprecated"
#         },
#         {
#             "id": 24,
#             "x": 2,
#             "y": 3,
#             "z": 1,
#             "url": "deprecated"
#         },
#         {
#             "id": 25,
#             "x": 3,
#             "y": 3,
#             "z": 1,
#             "url": "deprecated"
#         },
#         {
#             "id": 26,
#             "x": 4,
#             "y": 3,
#             "z": 1,
#             "url": "deprecated"
#         },
#         {
#             "id": 27,
#             "x": 0,
#             "y": 0,
#             "z": 2,
#             "url": "deprecated"
#         },
#         {
#             "id": 28,
#             "x": 1,
#             "y": 0,
#             "z": 2,
#             "url": "deprecated"
#         },
#         {
#             "id": 29,
#             "x": 2,
#             "y": 0,
#             "z": 2,
#             "url": "deprecated"
#         },
#         {
#             "id": 30,
#             "x": 3,
#             "y": 0,
#             "z": 2,
#             "url": "deprecated"
#         },
#         {
#             "id": 31,
#             "x": 4,
#             "y": 0,
#             "z": 2,
#             "url": "deprecated"
#         },
#         {
#             "id": 32,
#             "x": 5,
#             "y": 0,
#             "z": 2,
#             "url": "deprecated"
#         },
#         {
#             "id": 33,
#             "x": 6,
#             "y": 0,
#             "z": 2,
#             "url": "deprecated"
#         },
#         {
#             "id": 34,
#             "x": 7,
#             "y": 0,
#             "z": 2,
#             "url": "deprecated"
#         },
#         {
#             "id": 35,
#             "x": 8,
#             "y": 0,
#             "z": 2,
#             "url": "deprecated"
#         },
#         {
#             "id": 36,
#             "x": 0,
#             "y": 1,
#             "z": 2,
#             "url": "deprecated"
#         },
#         {
#             "id": 37,
#             "x": 1,
#             "y": 1,
#             "z": 2,
#             "url": "deprecated"
#         },
#         {
#             "id": 38,
#             "x": 2,
#             "y": 1,
#             "z": 2,
#             "url": "deprecated"
#         },
#         {
#             "id": 39,
#             "x": 3,
#             "y": 1,
#             "z": 2,
#             "url": "deprecated"
#         },
#         {
#             "id": 40,
#             "x": 4,
#             "y": 1,
#             "z": 2,
#             "url": "deprecated"
#         },
#         {
#             "id": 41,
#             "x": 5,
#             "y": 1,
#             "z": 2,
#             "url": "deprecated"
#         },
#         {
#             "id": 42,
#             "x": 6,
#             "y": 1,
#             "z": 2,
#             "url": "deprecated"
#         },
#         {
#             "id": 43,
#             "x": 7,
#             "y": 1,
#             "z": 2,
#             "url": "deprecated"
#         },
#         {
#             "id": 44,
#             "x": 8,
#             "y": 1,
#             "z": 2,
#             "url": "deprecated"
#         },
#         {
#             "id": 45,
#             "x": 0,
#             "y": 2,
#             "z": 2,
#             "url": "deprecated"
#         },
#         {
#             "id": 46,
#             "x": 1,
#             "y": 2,
#             "z": 2,
#             "url": "deprecated"
#         },
#         {
#             "id": 47,
#             "x": 2,
#             "y": 2,
#             "z": 2,
#             "url": "deprecated"
#         },
#         {
#             "id": 48,
#             "x": 3,
#             "y": 2,
#             "z": 2,
#             "url": "deprecated"
#         },
#         {
#             "id": 49,
#             "x": 4,
#             "y": 2,
#             "z": 2,
#             "url": "deprecated"
#         },
#         {
#             "id": 50,
#             "x": 5,
#             "y": 2,
#             "z": 2,
#             "url": "deprecated"
#         },
#         {
#             "id": 51,
#             "x": 6,
#             "y": 2,
#             "z": 2,
#             "url": "deprecated"
#         },
#         {
#             "id": 52,
#             "x": 7,
#             "y": 2,
#             "z": 2,
#             "url": "deprecated"
#         },
#         {
#             "id": 53,
#             "x": 8,
#             "y": 2,
#             "z": 2,
#             "url": "deprecated"
#         },
#         {
#             "id": 54,
#             "x": 0,
#             "y": 3,
#             "z": 2,
#             "url": "deprecated"
#         },
#         {
#             "id": 55,
#             "x": 1,
#             "y": 3,
#             "z": 2,
#             "url": "deprecated"
#         },
#         {
#             "id": 56,
#             "x": 2,
#             "y": 3,
#             "z": 2,
#             "url": "deprecated"
#         },
#         {
#             "id": 57,
#             "x": 3,
#             "y": 3,
#             "z": 2,
#             "url": "deprecated"
#         },
#         {
#             "id": 58,
#             "x": 4,
#             "y": 3,
#             "z": 2,
#             "url": "deprecated"
#         },
#         {
#             "id": 59,
#             "x": 5,
#             "y": 3,
#             "z": 2,
#             "url": "deprecated"
#         },
#         {
#             "id": 60,
#             "x": 6,
#             "y": 3,
#             "z": 2,
#             "url": "deprecated"
#         },
#         {
#             "id": 61,
#             "x": 7,
#             "y": 3,
#             "z": 2,
#             "url": "deprecated"
#         },
#         {
#             "id": 62,
#             "x": 8,
#             "y": 3,
#             "z": 2,
#             "url": "deprecated"
#         },
#         {
#             "id": 63,
#             "x": 0,
#             "y": 4,
#             "z": 2,
#             "url": "deprecated"
#         },
#         {
#             "id": 64,
#             "x": 1,
#             "y": 4,
#             "z": 2,
#             "url": "deprecated"
#         },
#         {
#             "id": 65,
#             "x": 2,
#             "y": 4,
#             "z": 2,
#             "url": "deprecated"
#         },
#         {
#             "id": 66,
#             "x": 3,
#             "y": 4,
#             "z": 2,
#             "url": "deprecated"
#         },
#         {
#             "id": 67,
#             "x": 4,
#             "y": 4,
#             "z": 2,
#             "url": "deprecated"
#         },
#         {
#             "id": 68,
#             "x": 5,
#             "y": 4,
#             "z": 2,
#             "url": "deprecated"
#         },
#         {
#             "id": 69,
#             "x": 6,
#             "y": 4,
#             "z": 2,
#             "url": "deprecated"
#         },
#         {
#             "id": 70,
#             "x": 7,
#             "y": 4,
#             "z": 2,
#             "url": "deprecated"
#         },
#         {
#             "id": 71,
#             "x": 8,
#             "y": 4,
#             "z": 2,
#             "url": "deprecated"
#         },
#         {
#             "id": 72,
#             "x": 0,
#             "y": 5,
#             "z": 2,
#             "url": "deprecated"
#         },
#         {
#             "id": 73,
#             "x": 1,
#             "y": 5,
#             "z": 2,
#             "url": "deprecated"
#         },
#         {
#             "id": 74,
#             "x": 2,
#             "y": 5,
#             "z": 2,
#             "url": "deprecated"
#         },
#         {
#             "id": 75,
#             "x": 3,
#             "y": 5,
#             "z": 2,
#             "url": "deprecated"
#         },
#         {
#             "id": 76,
#             "x": 4,
#             "y": 5,
#             "z": 2,
#             "url": "deprecated"
#         },
#         {
#             "id": 77,
#             "x": 5,
#             "y": 5,
#             "z": 2,
#             "url": "deprecated"
#         },
#         {
#             "id": 78,
#             "x": 6,
#             "y": 5,
#             "z": 2,
#             "url": "deprecated"
#         },
#         {
#             "id": 79,
#             "x": 7,
#             "y": 5,
#             "z": 2,
#             "url": "deprecated"
#         },
#         {
#             "id": 80,
#             "x": 8,
#             "y": 5,
#             "z": 2,
#             "url": "deprecated"
#         },
#         {
#             "id": 81,
#             "x": 0,
#             "y": 6,
#             "z": 2,
#             "url": "deprecated"
#         },
#         {
#             "id": 82,
#             "x": 1,
#             "y": 6,
#             "z": 2,
#             "url": "deprecated"
#         },
#         {
#             "id": 83,
#             "x": 2,
#             "y": 6,
#             "z": 2,
#             "url": "deprecated"
#         },
#         {
#             "id": 84,
#             "x": 3,
#             "y": 6,
#             "z": 2,
#             "url": "deprecated"
#         },
#         {
#             "id": 85,
#             "x": 4,
#             "y": 6,
#             "z": 2,
#             "url": "deprecated"
#         },
#         {
#             "id": 86,
#             "x": 5,
#             "y": 6,
#             "z": 2,
#             "url": "deprecated"
#         },
#         {
#             "id": 87,
#             "x": 6,
#             "y": 6,
#             "z": 2,
#             "url": "deprecated"
#         },
#         {
#             "id": 88,
#             "x": 7,
#             "y": 6,
#             "z": 2,
#             "url": "deprecated"
#         },
#         {
#             "id": 89,
#             "x": 8,
#             "y": 6,
#             "z": 2,
#             "url": "deprecated"
#         }
#     ]
# }

# %% [markdown]
# ---

# %% [markdown]
# ## Sets
# Below are snippets from the `sets.py` submodule, allowing you to access drawing sets.

# %% [markdown]
# ### `drawings.sets.get()`
# Fetches all the drawing sets for a project

# %%
drawing_sets = connection.drawings.sets.get(
    company_id=company["id"],
    project_id=project_id,
    per_page=100
)

print(f"Found {len(drawing_sets)} drawing sets")
if len(drawing_sets) > 0:
    print(f"\nFirst set:")
    print(json.dumps(drawing_sets[0], indent=4))
# Out:
# ---------------------------------------------------------------------------
# NotFoundClientError                       Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 drawing_sets = connection.drawings.sets.get(
#       2     company_id=company["id"],
#       3     project_id=project_id,
#       4     per_page=100
#       5 )
#       7 print(f"Found {len(drawing_sets)} drawing sets")
#       8 if len(drawing_sets) > 0:
#
# File ~/Projects/ProPyCore/ProPyCore/access/drawings/sets.py:40, in Sets.get(self, company_id, project_id, page, per_page)
#      30 headers = {
#      31     "Procore-Company-Id": f"{company_id}"
#      32 }
#      34 params = {
#      35     "project_id": project_id,
#      36     "page": page,
#      37     "per_page": per_page
#      38 }
# ---> 40 drawing_sets = self.get_request(
#      41     api_url=f"{self.endpoint}/drawing_sets",
#      42     additional_headers=headers,
#      43     params=params
#      44 )
#      46 return drawing_sets
#
# File ~/Projects/ProPyCore/ProPyCore/access/base.py:58, in Base.get_request(self, api_url, additional_headers, params)
#      56     return response.json()
#      57 else:
# ---> 58     raise_exception(response)
#
# File ~/Projects/ProPyCore/ProPyCore/exceptions.py:77, in raise_exception(response)
#      74     raise NoPrivilegeError(f"403: Data connection app or permission template does not have access to this endpoint", response.text)
#      76 elif response.status_code == 404:
# ---> 77     raise NotFoundClientError('404: Client ID doesn\'t exist', response.text)
#      79 elif response.status_code == 422:
#      80     raise UnprocessableContentError('422: A field that needs a unique value already exists', response.text)
#
# NotFoundClientError: "404: Client ID doesn't exist"

# %%
# Replace with your drawing set ID
drawing_set_id = 12345

drawing_set = connection.drawings.sets.show(
    company_id=company["id"],
    project_id=project_id,
    drawing_set_id=drawing_set_id
)

print(json.dumps(drawing_set, indent=4))

# %% [markdown]
# ---

# %% [markdown]
# ## Revisions
# Below are snippets from the `revisions.py` submodule, allowing you to access drawing revisions.

# %% [markdown]
# ### `drawings.revisions.get()`
# Fetches all the drawing revisions for a project

# %%
drawing_revisions = connection.drawings.revisions.get(
    company_id=company["id"],
    project_id=2685112,
    per_page=100
)

print(f"Found {len(drawing_revisions)} drawing revisions")
if len(drawing_revisions) > 0:
    print(f"\nFirst revision:")
    print(json.dumps(drawing_revisions[0], indent=4))
# Out:
# Found 2283 drawing revisions
#
# First revision:
# {
#     "id": 272725310,
#     "drawing_date": "2023-11-30",
#     "received_date": "2023-12-05",
#     "revision_number": "0",
#     "drawing_id": 119712792,
#     "custom_fields": {},
#     "floorplan": false,
#     "current": false,
#     "drawing_set": {
#         "id": 6709811
#     },
#     "drawing_sketches_count": 0,
#     "number": "A00-00",
#     "title": "STANDARDS AND SYMBOLS",
#     "has_public_markup_layer_elements": false,
#     "has_drawing_sketches": false,
#     "activity_stream_last_viewed_at": null,
#     "status": "published",
#     "obsolete": false,
#     "discipline": {
#         "id": 9446240,
#         "name": "Architectural",
#         "position": null
#     },
#     "height": 4571,
#     "pdf_size": 2852313,
#     "pdf_url": "https://storage.procore.com/api/v5/files/us-east-1/pro-core.com/2b1e91a7-87d4-4b14-b337-543165685cd2_production_1702066668_c25797889_p1.pdf?companyId=8089&projectId=2685112&sig=3b416e401b97816998267aab04df5c74736f4e0736ff4b91d19b79060deb78cc",
#     "png_size": 5533143,
#     "png_url": "https://storage.procore.com/api/v5/files/us-east-1/pro-core.com/403aa6aa-876b-4aa7-9618-1d7812c90404_production_1702066671_c25797889_p1.png?companyId=8089&projectId=2685112&sig=04632ab13bdd9f2b33713faab3fc29b51e2dcb69e32eaa168cb119a0de0fe5f4",
#     "updated_at": "2023-12-11T16:15:00Z",
#     "width": 6400,
#     "large_thumbnail_url": "https://storage.procore.com/api/v5/files/us-east-1/prostore-thumbnail-bucket-production/95644eb823fa924c70f1f6f34592c46c337a_4409066991_thumbnail_large_production.PNG?companyId=8089&projectId=2685112&sig=ce68dc0ae3cb8327ac26b34a6c750699642feb99890eb38c60a1ed30c8e66686",
#     "position": null,
#     "order_in_drawing": 3,
#     "zip_url": "https://storage.procore.com/api/v5/files/us-east-1/pro-core.com/272725310_09c56168-fd28-488b-b2b6-8e42b710d17c.zip?companyId=8089&projectId=2685112&sig=86ce853e52ca7da863474d99dd3ff210a92725d4f81ca2557cb12015bd41d005",
#     "thumbnail_url": "https://storage.procore.com/api/v5/files/us-east-1/prostore-thumbnail-bucket-production/2c72629838365df9a9418283db926d66ab8d_4409066991_thumbnail_small_production.PNG?companyId=8089&projectId=2685112&sig=abc61c5f93c366008274bebecc8fca714a5e0e63b459bb9c0b214a487bfa0f0b",
#     "drawing_area": {
#         "id": 2189052
#     }
# }

# %% [markdown]
# ### `drawings.revisions.show()`
# Show information from a single drawing revision

# %%
# Replace with your drawing revision ID
drawing_revision_id = 358220391

drawing_revision = connection.drawings.revisions.show(
    company_id=company["id"],
    project_id=project_id,
    drawing_revision_id=drawing_revision_id
)

print(json.dumps(drawing_revision, indent=4))
# Out:
# {
#     "id": 358220391,
#     "drawing_date": "2025-08-27",
#     "received_date": null,
#     "revision_number": "0",
#     "drawing_id": 156014309,
#     "custom_fields": {},
#     "floorplan": false,
#     "current": true,
#     "drawing_set": {
#         "id": 8962517,
#         "name": "Punch List Drawing Set",
#         "date": "2025-08-27"
#     },
#     "drawing_sketches_count": 0,
#     "number": "MEP01-03",
#     "title": "MEP FLOOR PLAN - PHASE ONE - LEVEL THREE - OVERALL",
#     "has_public_markup_layer_elements": true,
#     "has_drawing_sketches": false,
#     "activity_stream_last_viewed_at": null,
#     "status": "published",
#     "obsolete": false,
#     "discipline": {
#         "id": 9446335,
#         "name": "Mechanical",
#         "position": null
#     },
#     "connectability_outdated": false,
#     "height": 4571,
#     "pdf_size": 1442803,
#     "pdf_url": "https://storage.procore.com/api/v5/files/us-east-1/pro-core.com/8089/2685112/05a352bb-cf7f-4814-8383-a238278106bc_production_1756324555_c43739640_p8.pdf?companyId=8089&projectId=2685112&sig=44cb608c276b709e90c376229309a4837fda6440b2328a0cc57b3857aca6acc8",
#     "png_size": 2073710,
#     "png_url": "https://storage.procore.com/api/v5/files/us-east-1/pro-core.com/8089/2685112/50c8299d-69fb-432d-87cb-dd7e2af185cc_production_1756324555_c43739640_p8.png?companyId=8089&projectId=2685112&sig=a8ab4aa961fa1d560f19057cb6cb03937d826a68ce2ba4ca63d9f1b6fd00d101",
#     "updated_at": "2025-10-29T19:41:57Z",
#     "width": 6400,
#     "large_thumbnail_url": "https://storage.procore.com/api/v5/files/us-east-1/prostore-thumbnail-bucket-production/a7ecde1b-7c73-455a-b5f0-f5bc1840acae_5653703426_production_thumbnail_large?companyId=8089&projectId=2685112&sig=4aeaa0cb0bddb11192c7672fdf0f32a774dc8f29b99c72bc85effb95f538c2cb",
#     "position": null,
#     "order_in_drawing": 0,
#     "zip_url": "https://storage.procore.com/api/v5/files/us-east-1/pro-core.com/358220391_fba57cbd-101f-4628-919b-ee7cc1efbb31.zip?companyId=8089&projectId=2685112&sig=d986c201792264a7d38957d8a170c835c25e6054fadb77e3600ee000bf4438bb",
#     "thumbnail_url": "https://storage.procore.com/api/v5/files/us-east-1/prostore-thumbnail-bucket-production/a7ecde1b-7c73-455a-b5f0-f5bc1840acae_5653703426_production_thumbnail_small?companyId=8089&projectId=2685112&sig=7d48f2b252c8cca096125f3fac19b6121ae07964fa316f386979e578619659f6",
#     "drawing_area": {
#         "id": 2360649
#     }
# }

# %% [markdown]
# ---

# %% [markdown]
# ## Uploads
# Below are snippets from the `uploads.py` submodule, allowing you to access drawing uploads.

# %% [markdown]
# ### `drawings.uploads.get()`
# Fetches all the drawing uploads for a project

# %%
drawing_uploads = connection.drawings.uploads.get(
    company_id=company["id"],
    project_id=project_id,
    per_page=100
)

print(f"Found {len(drawing_uploads)} drawing uploads")
if len(drawing_uploads) > 0:
    print(f"\nFirst upload:")
    print(json.dumps(drawing_uploads[0], indent=4))

# %% [markdown]
# ### `drawings.uploads.show()`
# Show information from a single drawing upload

# %%
# Replace with your drawing upload ID
drawing_upload_id = 12345

drawing_upload = connection.drawings.uploads.show(
    company_id=company["id"],
    project_id=project_id,
    drawing_upload_id=drawing_upload_id
)

print(json.dumps(drawing_upload, indent=4))
